# %%
import pandas as pd

# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# absl-py                                  2.1.0
# aiofiles                                 22.1.0
# aiohttp                                  3.9.3
# aiohttp-cors                             0.7.0
# aiorwlock                                1.4.0
# aiosignal                                1.3.1
# aiosqlite                                0.20.0
# anyio                                    4.3.0
# archspec                                 0.2.3
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asttokens                                2.4.1
# async-timeout                            4.0.3
# attrs                                    23.2.0
# Babel                                    2.14.0
# beatrix_jupyterlab                       2024.129.184238
# ...

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 3.4 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.covid19_ecdc.covid_19_geographic_distribution_worldwide` LIMIT 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          date  day  month  year  daily_confirmed_cases  daily_deaths  \
# 0  2019-12-31   31     12  2019                      0             0
# 1  2019-12-31   31     12  2019                      0             0
# 2  2019-12-31   31     12  2019                      0             0
# 3  2019-12-31   31     12  2019                      0             0
# 4  2019-12-31   31     12  2019                      0             0
# 5  2019-12-31   31     12  2019                      0             0
# 6  2019-12-31   31     12  2019                      0             0
# 7  2019-12-31   31     12  2019                      0             0
# 8  2019-12-31   31     12  2019                      0             0
# 9  2019-12-31   31     12  2019                      0             0
#
#    confirmed_cases  deaths                   countries_and_territories  \
# ...
